# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook we talk about some tools for data science and simple Python codes.

# %% [markdown]
# **Objectives:**
# * List common Languages for data science
# * List common libraries for data science
# * List common data science tools
# * Apply arithmetic operations
# * Deliver the proves of lab implementation

# %% [markdown]
# These are some common languages used for data science:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java

# %% [markdown]
# These are some common libraries used by data scientists:
# 1. Pandas
# 2. Numpy
# 3. Maplotlib
# 4. Seaborn
# 5. Scikit-learn

# %% [markdown]
# |Data Science Tools|
# |-----------|
# |Jupyter Notebook|
# |RStudio|
# |Visual Studio Code|

# %% [markdown]
# ### Here are some examples of arithmetic expressions

# %%
# This is an example of the use of arithmetic expressions using Python, we multiple two numbers and add another one.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes into hours by dividing the minutes by 60
minutes= 200
hours=minutes/60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# David Grisales Posada

# %% [markdown]
# # Screenshots
# ![1-notebook.png](attachment:377122f1-d242-424b-b18e-97bd4e8e2198.png)

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
