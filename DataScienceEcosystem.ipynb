# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * List common Languages for data science
# * List common libraries for data science
# * List common data science tools
# * Apply arithmetic operations
# * Deliver the proves of lab implementation

# %% [markdown]
# These are some common languages used for data science:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java

# %% [markdown]
# These are some common libraries used by data scientists:
# 1. Pandas
# 2. Numpy
# 3. Maplotlib
# 4. Seaborn
# 5. Scikit-learn

# %% [markdown]
# |Data Science Tools|
# |-----------|
# |Jupyter Notebook|
# |RStudio|
# |Visual Studio Code|

# %% [markdown]
# ### Here are some examples of arithmetic expressions

# %%
# This is an example of the use of arithmetic expressions using Python, we multiple two numbers and add another one.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes into hours by dividing the minutes by 60
minutes= 200
hours=minutes/60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# David Grisales Posada

# %% [markdown]
# # Screenshots
# ![2-title.png](attachment:95da7be5-c61d-41c0-863e-9478a59ffc8a.png)
# ![3-into.png](attachment:493fa12c-3660-4edd-97e1-208f38b9e076.png)
# ![4-dslanguages.png](attachment:6af98420-accd-48cc-a7f5-b214776356c6.png)
# ![5-dslibraries.png](attachment:185e4dc7-b820-40f7-a682-734cc9901aaa.png)
# ![6-dstools.png](attachment:07cf243d-2992-47c4-b88a-b36687ef2bce.png)
# ![7-introarithmetic.png](attachment:4d52e01f-fb4c-47b0-a243-d164f9ff4060.png)
# ![8-multiplyandaddintegers.png](attachment:7c7f17c4-c181-4e70-b21f-070e5ee55ad7.png)
# ![9-hourstominutes.png](attachment:ece98a37-625d-4a32-a1f0-89bbeff335da.png)
# ![10-objectives.png](attachment:b5fe3df3-1959-40cc-895b-5997526029dc.png)
# ![11-authordetails.png](attachment:439c5569-8119-4cbe-8d75-540680fd759a.png)
